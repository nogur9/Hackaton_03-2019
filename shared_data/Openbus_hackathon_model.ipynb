# %%
#imports

import pandas as pd
import numpy as np
import math

pd.options.display.max_columns =200
pd.options.display.max_rows =500
pd.options.display.max_colwidth =500

# %% [markdown]
# ## Get train data

# %%
train = pd.read_csv('train.csv', encoding='windows-1255')

# %%
train.head()
# Out:
#    trip_index   bus_id time_recorded        lat        lon  route_id  \
# 0           3  7508169      18:54:00  32.054939  34.779751     20920
# 1           3  7508169      18:58:01  32.055996  34.779331     20920
# 2           3  7508169      18:59:17  32.056160  34.778408     20920
# 3           3  7508169      19:00:18  32.056400  34.780128     20920
# 4           3  7508169      19:03:13  32.061306  34.784782     20920
#
#    line_index
# 0         169
# 1         173
# 2         174
# 3         175
# 4         178

# %% [markdown]
# trip_index = main key

# %%
print (len(train), train.trip_index.nunique())
# Out:
# 127227 2248

# %%
train.drop_duplicates(subset=['trip_index']).route_id.value_counts()
# Out:
# 5189     1328
# 20920     392
# 20916     268
# 5214      194
# 20912      66
# Name: route_id, dtype: int64

# %%
train.groupby('trip_index').bus_id.nunique().value_counts()
# Out:
# 1    2233
# 2      15
# Name: bus_id, dtype: int64

# %%
X = pd.DataFrame()
for trip_index in train.trip_index.unique():
# Out:
#   File "<ipython-input-7-483f058e0595>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# trips with bus change?

# %% [markdown]
# ## get route_stats data

# %%
route_stats = pd.read_csv('route_stats.csv', index_col=[0])
#route_stats = pd.read_csv('route_stats_1.csv.gz')

# %%
train[train.trip_index == 3].route_id[0]

# %%
len(route_stats[route_stats.route_id == 20920].all_stop_id.iloc[0].split(";"))

# %%
print (len(route_stats), len(route_stats.drop_duplicates(subset=['route_id','date'])))

# %% [markdown]
# ## choose relavents dates

# %%
#START_DATE = pd.datetime(2019,2,1)
#END_DATE = pd.datetime(2019,3,14)

# %%
#print (route_stats['date'].min(),route_stats['date'].max())

# %%
#route_stats = route_stats[(pd.to_datetime(route_stats['date'])>=START_DATE)&
 #                        (pd.to_datetime(route_stats['date'])<=END_DATE)]

# %%
print (route_stats['date'].min(),route_stats['date'].max())

# %% [markdown]
# ## send route_stats to csv

# %%
#route_stats.to_csv('route_stats.csv')

# %% [markdown]
# ## find unique routes
# *driving paths may change from time to time

# %%
route_stats.groupby('route_id').all_stop_id.nunique()

# %%
train.groupby(['trip_index', 'lat','lon']).head()

# %%
train_unique = train.groupby(['trip_index'], as_index=False).g['lat','lon']

# %%
train_unique.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d641bf10cc6b> in <module>
# ----> 1 train_unique.head()
#
# NameError: name 'train_unique' is not defined

# %%
route_stats_unique = route_stats.groupby(['route_id','all_stop_id','all_stop_latlon'],
                                        as_index=False)['date'].agg(['min','max'])\
                                        .rename(columns = {'min':'start_date', 'max': 'end_date'})\
                                        .reset_index().sort_values(by = ['route_id','start_date'])

# %%
route_stats_unique

# %% [markdown]
# ## plot routes

# %% [markdown]
# ####  route_stats_split_coordinates

# %%
def route_stats_split_coordinates(route_id):
    coordinates_strings = [latlon.split(',') for latlon in route_id.all_stop_latlon.split(';')]
    coordinates_floats = [(float(lat), float(lon)) for lat, lon in coordinates_strings]
    
    return coordinates_floats

# %%
route_stats_unique.apply(lambda r: route_stats_split_coordinates(r), axis=1).tolist()[0][:3]

# %% [markdown]
# ####  route_stats_split_stops

# %%
def route_stats_split_stops(route_id, col):
    return route_id[col].split(';')

# %%
route_stats_unique.apply(lambda r: route_stats_split_stops(r, 'all_stop_id'), axis=1).tolist()[0][:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c1d38dc96057> in <module>
# ----> 1 route_stats_unique.apply(lambda r: route_stats_split_stops(r, 'all_stop_id'), axis=1).tolist()[0][:3]
#
# NameError: name 'route_stats_unique' is not defined

# %% [markdown]
# ####  route_stats_2_stops

# %%
def route_stats_2_stops(route_stats):
    
    route_stats = route_stats.copy()
    
    route_stats_stops = pd.DataFrame(columns = ['route_id','stop_index','stop_id','coordinates'])
    
    route_stats['all_stop_latlon'] = route_stats.apply(lambda r: route_stats_split_coordinates(r), axis=1)
    route_stats['all_stop_id'] = route_stats.apply(lambda r: route_stats_split_stops(r, 'all_stop_id'), axis=1)
    
    for route_id in route_stats['route_id']:
        route_id_stops = pd.DataFrame()
        route_id_stops['stop_id'] = pd.Series(route_stats[route_stats['route_id']==route_id]['all_stop_id'].tolist()[0])
        route_id_stops['coordinates'] = pd.Series(route_stats[route_stats['route_id']==route_id]['all_stop_latlon'].tolist()[0])
        route_id_stops['stop_index'] = route_id_stops.index+1
        route_id_stops['route_id'] = route_id
        
        route_stats_stops = route_stats_stops.append(route_id_stops)
    
    route_stats_stops = route_stats_stops[['route_id','stop_index','stop_id','coordinates']]\
            .sort_values(by = ['route_id','stop_index'])
    
    return route_stats_stops

# %%
route_stats_stops = route_stats_2_stops(route_stats_unique)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0569ae0f1511> in <module>
# ----> 1 route_stats_stops = route_stats_2_stops(route_stats_unique)
#
# NameError: name 'route_stats_unique' is not defined

# %%
route_stats_stops.head()
# Out:
#   route_id stop_index stop_id                      coordinates
# 0     5189          1   37687  (32.055909, 34.779084999999995)
# 1     5189          2   29310  (32.061294000000004, 34.784812)
# 2     5189          3   29322           (32.067008, 34.786971)
# 3     5189          4   13320           (32.074292, 34.791025)
# 4     5189          5   13354           (32.083907, 34.795093)

# %% [markdown]
# #### plot with geopandas

# %%
# %matplotlib inline

from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt
import geopandas as gpd
#from seaborn import palplot

# %%
def plot_route_id_stops(route_stats_stops):
    route_stats_stops['coordinates'] = route_stats_stops['coordinates'].apply(Point)
    gdf = gpd.GeoDataFrame(route_stats_stops, geometry='coordinates')
    
    route_ids = dict(tuple(gdf.groupby('route_id')))
    
    fig = plt.figure(num=None, figsize=(10, 8))
    
    first_route_id = list(route_ids.keys())[0]
    
    ax = route_ids[first_route_id].plot()
    
    for route_id in route_ids.keys():
        if route_id == first_route_id:
            pass
        else:
            route_ids[route_id].plot(ax=ax)

# %%
plot_route_id_stops(route_stats_stops)

# %%
plot_route_id_stops(route_stats_stops[route_stats_stops.route_id==5189])
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_route_id_stops(route_stats_stops[route_stats_stops.route_id.isin([20916])])
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_route_id_stops(route_stats_stops[route_stats_stops.route_id.isin([20917])])
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# route_id 20916 and route_id 20917 are very similar

# %% [markdown]
# ##  match siri data to route_id using geopandas buffer

# %% [markdown]
# ### transform route_stats_stops to  GeoDataFrame & set buffer for stops

# %%
def set_buffer(route_stats_stops, buffer_rad = 0.01):
    route_stats_stops['coordinates'] = route_stats_stops['coordinates'].apply(Point)
    gdf = gpd.GeoDataFrame(route_stats_stops, geometry='coordinates')
    gdf['buffer'] = gdf.buffer(buffer_rad)
    gdf.set_index('stop_id', inplace=True, drop=False)
    
    return gdf

# %%
route_stats_stops_gdf = set_buffer(route_stats_stops)

# %%
route_stats_stops_gdf.head(3)
# Out:
#         route_id stop_index stop_id                          coordinates  \
# stop_id
# 37687       5189          1   37687  POINT (32.055909 34.77908499999999)
# 29310       5189          2   29310          POINT (32.061294 34.784812)
# 29322       5189          3   29322          POINT (32.067008 34.786971)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       buffer
# stop_id
# 37687    POLYGON ((32.065909 34.77908499999999, 32.06586084726672 34.7781048285967, 32.06571685280403 34.77713409677983, 32.06547840335733 34.77618215322745, 32.06514779532511 34.77525816567634, 32.06472821264348 34.77437103263173, 32.06422369612302 34.7735292976698, 32.06363910453363 34.77274106715836, 32.06298006781186 34.77201393218813, 32.06225293284164 34.77135489546637, 32.0614647023302 34.77077030387697, 32.06062296736826 34.77026578735651, 32.05973583432365 34.76984620467488, 32.0588118467725...
# 29310    POLYGON ((32.071294 34.784812, 32.07124584726672 34.7838318285967, 32.07110185280403 34.78286109677984, 32.07086340335733 34.78190915322746, 32.07053279532511 34.78098516567635, 32.07011321264348 34.78009803263174, 32.06960869612303 34.7792562976698, 32.06902410453363 34.77846806715836, 32.06836506781187 34.77774093218814, 32.06763793284164 34.77708189546637, 32.0668497023302 34.77649730387698, 32.06600796736826 34.77599278735652, 32.06512083432366 34.77557320467489, 32.06419684677255 34.775...
# 29322    POLYGON ((32.077008 34.786971, 32.07695984726672 34.7859908285967, 32.07681585280403 34.78502009677984, 32.07657740335733 34.78406815322746, 32.07624679532511 34.78314416567635, 32.07582721264348 34.78225703263174, 32.07532269612302 34.7814152976698, 32.07473810453363 34.78062706715836, 32.07407906781187 34.77989993218814, 32.07335193284164 34.77924089546637, 32.0725637023302 34.77865630387698, 32.07172196736826 34.77815178735652, 32.07083483432366 34.77773220467489, 32.06991084677254 34.777...

# %% [markdown]
# ### transform train to  GeoDataFrame

# %%
train.head()
# Out:
#    trip_index   bus_id time_recorded        lat        lon  route_id  \
# 0           3  7508169      18:54:00  32.054939  34.779751     20920
# 1           3  7508169      18:58:01  32.055996  34.779331     20920
# 2           3  7508169      18:59:17  32.056160  34.778408     20920
# 3           3  7508169      19:00:18  32.056400  34.780128     20920
# 4           3  7508169      19:03:13  32.061306  34.784782     20920
#
#    line_index
# 0         169
# 1         173
# 2         174
# 3         175
# 4         178

# %%
train['coordinates'] = list(zip(train.lat, train.lon))
train['coordinates'] = train['coordinates'].apply(Point)

train_gdf = gpd.GeoDataFrame(train, geometry='coordinates')

# %%
train_gdf.head()
# Out:
#    trip_index   bus_id time_recorded        lat        lon  route_id  \
# 0           3  7508169      18:54:00  32.054939  34.779751     20920
# 1           3  7508169      18:58:01  32.055996  34.779331     20920
# 2           3  7508169      18:59:17  32.056160  34.778408     20920
# 3           3  7508169      19:00:18  32.056400  34.780128     20920
# 4           3  7508169      19:03:13  32.061306  34.784782     20920
#
#    line_index                                  coordinates
# 0         169  POINT (32.05493927001953 34.77975082397461)
# 1         173  POINT (32.05599594116211 34.77933120727539)
# 2         174  POINT (32.05615997314453 34.77840805053711)
# 3         175  POINT (32.05640029907227 34.78012847900391)
# 4         178  POINT (32.06130599975586 34.78478240966797)

# %% [markdown]
# ### define similarity metric

# %%
def find_route_id_similarity(trip, route_stats_stops_gdf, route_stats_unique):
    similarity_summary = {}
    
    for route_id in route_stats_unique.route_id:
    
        route_id_buffers = route_stats_stops_gdf[route_stats_stops_gdf['route_id']==route_id]['buffer'] 
    
        route_id_stops_results = {key: trip.within(geom) for key, geom in route_id_buffers.items()}
    
        route_id_stops_summary = {}
        for stop in route_id_stops_results.keys():
            route_id_stops_summary[stop] = np.any(route_id_stops_results[stop])
    
        route_id_mean = np.mean(list(route_id_stops_summary.values()))
        
        route_id_count = len(route_id_stops_summary)
    
        similarity_summary[str(route_id)+'_mean'] = [route_id_mean]
        
        similarity_summary[str(route_id)+'_cnt'] = [route_id_count]

    return pd.DataFrame(similarity_summary)

# %%
train_gdf.groupby(['trip_index',
                'route_id']).head(1)
# Out:
#         trip_index   bus_id time_recorded        lat        lon  route_id  \
# 0                3  7508169      18:54:00  32.054939  34.779751     20920
# 67               4  7793169      06:18:52  32.055027  34.779896     20916
# 142              6  7643869      06:46:22  32.055656  34.779430      5189
# 185              7  7711169      05:45:35  32.055809  34.779369     20916
# 248              8  7535069      17:35:00  32.055634  34.779621     20920
# 321              9  8732901      18:12:14  32.055538  34.779831      5214
# 389             12  8837201      08:07:23  32.055679  34.779434      5189
# 443             13  7643069      20:40:00  32.055576  34.779705      5189
# 496             17  7565269      10:24:01  32.055145  34.779957     20920
# 565             18  7508769      18:28:01  32.055817  34.779350     20920
# 632             20  7760869      11:26:39  32.055084  34.779900     20920
# 697             23  7647969      14:50:01  32.055218  34.780190      5189
# 754             24  8861401      10:43:01  32.055847  34.779312      5189
# 809             28  8825301      15:16:21  32.054981  34.779854      5189
# 873             32  7647469      06:22:01  32.055908  34.779255      5189
# 925             33  8891601      06:06:50  32.055859  34.779350      5189
# 975             34  8789001      14:10:00  32.055828  34.779339      5214
# 1041            35  8789001      13:35:43  32.055302  34.780163     20916
# 1125            36  7647369      06:14:00  32.055824  34.779301      5189
# 1179            37  7550269      12:10:00  32.055851  34.779366      5214
# 1242            40  7511269      19:41:02  32.054989  34.779720     20916
# 1313            41  7621669      07:03:39  32.055012  34.779846      5189
# 1370            42  7793169      06:31:56  32.073612  34.790901     20916
# 1373            46  8837401      09:23:17  32.056084  34.778381      5189
# 1428            47  7565269      14:20:00  32.055847  34.779331     20920
# 1497            49  7643869      06:57:52  32.066826  34.786880      5189
# 1532            51  7647969      14:47:35  32.054970  34.779850      5189
# 1597            52  8845201      07:37:21  32.055889  34.779209      5189
# 1659            54  8873801      15:43:04  32.054958  34.779839      5189
# 1722            56  7647369      11:15:15  32.169685  34.852947      5189
# 1737            58  8827201      08:53:47  32.055790  34.779774      5189
# 1793            61  7654269      18:48:24  32.055084  34.779934      5189
# 1861            62  8860201      14:32:43  32.055611  34.779697      5189
# 1864            66  8874601      08:01:02  32.055218  34.780182      5189
# 1922            68  8874901      06:59:06  32.056351  34.780163      5189
# 1978            69  7643869      10:31:29  32.055931  34.779305      5189
# 2034            70  8707001      17:31:11  32.093590  34.817577     20920
# 2082            74  7577969      13:53:00  32.056637  34.779667     20920
# 2152            78  8732501      12:41:55  32.055634  34.779545     20916
# 2236            82  7643869      10:31:06  32.055897  34.779285      5189
# 2286            85  7602969      23:10:21  32.056072  34.778378      5189
# 2327            87  8861401      07:47:00  32.055126  34.779858      5189
# 2382            88  7793369      20:46:41  32.056068  34.778355     20916
# 2421            89  8821101      06:31:40  32.061153  34.784908      5189
# 2425            91  7636369      20:11:08  32.054989  34.779861      5189
# 2473            92  7661669      09:05:24  32.055771  34.779377      5189
# 2537            93  7517769      17:06:43  32.055595  34.779633     20912
# 2539            96  8891501      09:25:26  32.055927  34.779358      5189
# 2590            98  7708169      11:10:55  32.055595  34.779617      5214
# 2653            99  8864501      14:31:23  32.056026  34.779377      5189
# 2717           102  8730201      11:23:47  32.055035  34.779903     20920
# 2721           104  8873901      15:01:31  32.055279  34.779999      5189
# 2780           105  8896501      14:15:00  32.054974  34.779766      5189
# 2832           107  8872501      15:43:02  32.056080  34.778343      5189
# 2895           110  7535069      17:36:58  32.055027  34.779934     20920
# 2970           111  7662369      09:06:32  32.055275  34.780029      5189
# 3030           112  7760869      16:07:09  32.055092  34.779999     20912
# 3097           113  8783801      17:30:33  32.095436  34.794250     20912
# 3133           115  7647469      07:45:13  32.055016  34.779842      5189
# 3195           116  8883401      11:46:29  32.055225  34.780090      5189
# 3238           117  7614769      11:07:00  32.055679  34.779804      5189
# 3299           120  7646969      21:55:27  32.055717  34.779297      5189
# 3338           121  7565169      11:54:30  32.055069  34.779804     20920
# 3408           123  7643869      06:46:17  32.055553  34.779922      5189
# 3461           124  7577969      09:23:00  32.055901  34.779369     20920
# 3527           128  7763869      13:23:55  32.055637  34.779774     20920
# 3600           129  7646969      08:19:17  32.056156  34.778381      5189
# 3656           132  8897801      16:54:07  32.055695  34.779781      5189
# 3714           134  7602969      00:00:53  32.180397  34.874573      5189
# 3756           135  8837201      12:45:00  32.055935  34.779240      5189
# 3814           136  7577969      17:45:24  32.055180  34.780174     20916
# 3898           139  8730201      16:07:29  32.055176  34.779865     20912
# 3903           140  7517769      12:26:43  32.054977  34.779739     20920
# 3975           143  7761169      16:23:57  32.055607  34.779652     20920
# 4043           144  8710901      17:10:03  32.055019  34.779942      5214
# 4047           145  7627669      17:57:11  32.056084  34.779305      5189
# 4113           146  7569969      17:10:00  32.055595  34.779640      5214
# 4190           148  7621669      19:09:02  32.055077  34.779881      5189
# 4242           150  8717301      13:35:06  32.056305  34.780060     20916
# 4332           151  7646569      09:58:46  32.056046  34.778381      5189
# 4383           154  8824501      19:07:26  32.055702  34.779362      5189
# 4439           156  8897801      09:25:41  32.055943  34.779305      5189
# 4481           160  8874101      15:30:17  32.056011  34.779282      5189
# 4537           162  7775169      15:07:25  32.055084  34.779987     20912
# 4540           163  8893001      16:25:36  32.055084  34.779778      5189
# 4597           166  8846601      08:39:27  32.066841  34.786793      5189
# 4598           167  8882501      11:05:13  32.055889  34.779308      5189
# 4649           169  7620669      16:41:24  32.055176  34.779953      5189
# 4718           173  8783801      12:53:07  32.055573  34.779713     20920
# 4794           176  7565969      16:23:55  32.055767  34.779427     20920
# 4865           178  8829801      17:15:08  32.055595  34.779610      5189
# 4926           180  7602969      00:00:58  32.182034  34.867279      5189
# 4970           183  8897801      13:04:07  32.055866  34.779263      5189
# 4973           184  7577969      09:31:04  32.056141  34.778381     20920
# 5038           185  8839501      20:55:00  32.055614  34.779507      5189
# 5093           186  7793169      14:45:00  32.056385  34.780193     20920
# 5172           187  7647769      09:09:35  32.056110  34.778385      5189
# 5228           188  8872401      19:57:18  32.055149  34.779907      5189
# 5277           192  7774969      13:41:32  32.055103  34.779987     20916
# 5353           193  8874601      13:04:13  32.055710  34.779377      5189
# 5407           194  8737001      17:53:00  32.055748  34.779732     20920
# 5478           197  7515269      08:05:00  32.055710  34.779789     20912
# 5509           198  7655069      17:58:14  32.054947  34.779739      5189
# 5580           202  8735801      13:36:06  32.055737  34.779480     20916
# 5663           203  8872401      15:31:34  32.055897  34.779282      5189
# 5729           206  7775269      17:20:41  32.055870  34.779343     20920
# 5819           207  7602969      11:11:33  32.141850  34.801884      5189
# 5853           212  8873801      08:15:25  32.054943  34.779789      5189
# 5888           215  7580269      15:53:00  32.055889  34.779350     20920
# 5968           216  8882501      07:16:30  32.055622  34.779598      5189
# 6030           217  8880401      10:53:16  32.055099  34.779392      5189
# 6087           219  7643069      17:11:12  32.055023  34.779884      5189
# 6146           220  8845201      08:38:39  32.152271  34.806156      5189
# 6175           222  7648069      06:22:00  32.055882  34.779243      5189
# 6227           226  7647769      17:06:02  32.055779  34.779552     20912
# 6282           227  7513969      19:25:07  32.055042  34.779900     20920
# 6345           228  8874701      07:30:00  32.055912  34.779274      5189
# 6379           229  8830701      09:36:32  32.055096  34.780045      5189
# 6431           230  7647469      18:28:36  32.055820  34.779289      5189
# 6499           231  7564969      18:32:29  32.056122  34.778397     20920
# 6570           234  8892901      16:40:58  32.056095  34.778374      5189
# 6633           235  7785269      16:23:31  32.055695  34.779774     20920
# 6717           236  8824501      18:09:15  32.054993  34.779842      5189
# 6776           237  7648169      08:27:55  32.055119  34.779976      5189
# 6831           238  7621669      07:02:19  32.055737  34.779819      5189
# 6880           239  7550269      12:11:14  32.055157  34.780087      5214
# 6945           240  7654369      11:47:24  32.055054  34.779793      5189
# 7010           242  8837201      08:37:29  32.113079  34.792782      5189
# 7052           244  7636369      20:12:25  32.055096  34.779846      5189
# 7104           247  7653569      16:39:13  32.056053  34.778355      5189
# 7159           248  7578269      09:42:10  32.055042  34.779903     20916
# 7234           250  7647869      16:41:05  32.055225  34.779980     20916
# 7324           252  8873701      05:40:34  32.055115  34.779980      5189
# 7381           253  8821101      00:01:02  32.174202  34.851810      5189
# 7432           254  7646669      07:59:30  32.055828  34.779289      5189
# 7496           256  7648069      21:25:30  32.055859  34.779243      5189
# 7549           257  7647969      17:42:52  32.055031  34.779911      5189
# 7607           258  8879301      08:35:26  32.055916  34.779270      5189
# 7667           260  7577969      09:25:04  32.054958  34.779816     20920
# 7733           262  7512569      09:15:00  32.055847  34.779713     20920
# 7799           263  7647969      00:00:00  32.108974  34.792114      5189
# 7858           265  7647469      09:50:40  32.056076  34.778347      5189
# 7914           266  8861601      18:46:21  32.055325  34.779907      5189
# 7972           267  7708169      07:05:20  32.055183  34.780018      5214
# 8046           268  8896501      06:54:00  32.055695  34.779549      5189
# 8105           269  7793169      10:26:03  32.056671  34.779392     20920
# 8179           270  7708169      15:17:54  32.056114  34.778397      5214
# 8257           271  7564969      08:13:53  32.055019  34.779827      5214
# 8326           272  8789001      18:42:15  32.055279  34.780128     20916
# 8405           274  7576469      05:25:00  32.055344  34.780174     20920
# 8463           275  7775169      19:11:17  32.055202  34.780048      5214
# 8528           277  8887401      23:00:00  32.055695  34.779217      5189
# 8571           279  7654269      18:48:18  32.055050  34.779938      5189
# 8630           285  8887401      11:31:18  32.055725  34.779770      5189
# 8688           286  8873801      22:45:08  32.055275  34.779922      5189
# 8730           287  8827201      17:33:27  32.060551  34.784607      5189
# 8797           289  7642669      11:15:17  32.054993  34.779892      5189
# 8855           290  7646869      11:25:00  32.055626  34.779644      5189
# 8911           291  8882301      05:25:16  32.055084  34.780014      5189
# 8952           292  7647669      11:25:24  32.055935  34.779228      5189
# 9017           293  7620669      06:35:25  32.056316  34.780392      5189
# 9050           294  7564969      07:47:55  32.055000  34.779896     20916
# 9132           299  8837201      08:07:00  32.055634  34.779377      5189
# 9187           302  7511269      16:53:18  32.055138  34.779938     20920
# 9269           303  8837201      19:07:23  32.055733  34.779392      5189
# 9320           305  7564969      17:45:33  32.055233  34.779884     20916
# 9322           306  7602969      00:00:16  32.056343  34.780285      5189
# 9360           308  7511269      18:54:32  32.055901  34.779613     20920
# 9422           314  8896501      14:15:02  32.055855  34.779282      5189
# 9480           315  7566369      17:36:05  32.055012  34.779953     20920
# 9547           316  7647369      10:07:00  32.055889  34.779297      5189
# 9601           317  8873901      15:01:16  32.055737  34.779781      5189
# 9604           319  7569969      13:28:11  32.055656  34.779617     20920
# 9680           320  8837201      15:15:57  32.055752  34.779350      5189
# 9740           321  8824501      14:47:00  32.055592  34.779709      5189
# 9804           322  8877601      05:25:00  32.055660  34.779396      5189
# 9847           323  7646769      08:39:31  32.162983  34.823166      5189
# 9874           325  8807501      15:57:43  32.055470  34.779842      5189
# 9935           326  8812901      21:25:30  32.055290  34.780087      5189
# 9990           331  7577969      18:25:41  32.055096  34.779957     20920
# 10062          334  8837601      19:35:00  32.056278  34.778538      5189
# 10114          337  7621669      06:41:13  32.055710  34.779743      5189
# 10177          338  7647469      22:28:13  32.055222  34.779957      5189
# 10221          343  7655069      16:25:16  32.055260  34.779800      5189
# 10291          344  7647569      21:55:01  32.055820  34.779308      5189
# 10340          345  7648369      09:25:00  32.055832  34.779324      5189
# 10401          348  7648169      08:37:29  32.055023  34.779858      5189
# 10451          350  7647969      07:02:14  32.055828  34.779839      5189
# 10508          351  8825301      19:08:58  32.055332  34.779884      5189
# 10565          353  8730201      20:01:40  32.055035  34.779915     20920
# 10630          354  8825301      15:15:02  32.055901  34.779335      5189
# 10698          357  7602969      07:15:06  32.057831  34.783859      5189
# 10749          360  8896501      11:07:30  32.055260  34.779747      5189
# 10804          362  7617769      05:10:00  32.055565  34.779865      5189
# 10846          365  8725401      18:23:41  32.055580  34.779774     20920
# 10916          366  8827201      20:55:19  32.055321  34.780056      5189
# 10979          369  7760869      16:08:27  32.054974  34.779835     20912
# 10983          371  7647669      07:38:16  32.055058  34.779884      5189
# 11044          372  8877101      06:30:19  32.055725  34.779366      5189
# 11081          373  8896501      06:54:14  32.055904  34.779316      5189
# 11139          375  8707001      12:26:53  32.055099  34.779884     20920
# 11206          377  7760869      20:04:02  32.055119  34.779991     20920
# 11270          378  8883401      11:45:57  32.056248  34.778606      5189
# 11325          379  7646569      10:40:10  32.055828  34.779247      5189
# 11380          381  7515269      16:14:08  32.055073  34.779961      5214
# 11383          384  8837801      16:11:10  32.055809  34.779774      5189
# 11438          387  8878001      23:00:26  32.055763  34.779163      5189
# 11483          388  7643869      12:26:23  32.055359  34.779911      5189
# 11533          389  8826201      17:29:37  32.055054  34.779896      5189
# 11596          390  7565169      09:37:38  32.055485  34.780170      5214
# 11657          391  7708169      15:10:00  32.055683  34.779579      5214
# 11660          392  7576469      05:25:27  32.055260  34.780136     20920
# 11680          394  7708169      07:05:00  32.055809  34.779388      5214
# 11746          396  7602969      00:00:01  32.095211  34.794434      5189
# 11786          398  7774969      06:25:01  32.055870  34.779354     20916
# 11864          400  7602969      00:00:17  32.056377  34.780243      5189
# 11898          402  7647569      15:57:30  32.055923  34.779305      5189
# 11959          403  8826201      09:37:15  32.054977  34.779556      5189
# 12006          405  7620669      09:45:00  32.055607  34.779579      5189
# 12072          406  8845801      13:30:34  32.055382  34.779716      5189
# 12125          407  8837201      08:03:39  32.055634  34.779377      5189
# 12126          408  7569969      17:45:00  32.055473  34.779900     20916
# 12207          409  8839501      11:35:17  32.055725  34.779781      5189
# 12263          411  8717301      18:11:09  32.055092  34.779812      5214
# 12266          412  8864501      17:59:32  32.055080  34.779995      5189
# 12329          414  8879301      21:55:01  32.055737  34.779327      5189
# 12381          417  8826101      20:56:04  32.054962  34.779812      5189
# 12443          419  7615169      06:35:39  32.055050  34.779877      5189
# 12498          422  8883401      11:45:27  32.055519  34.779736      5189
# 12549          423  7565269      10:13:15  32.054993  34.779903      5214
# 12614          424  7775169      15:11:08  32.056099  34.778305     20912
# 12669          426  8735801      17:53:13  32.055676  34.779499     20920
# 12742          430  7577969      09:24:39  32.055012  34.779953     20920
# 12810          431  7565169      17:05:52  32.055885  34.779350     20912
# 12868          434  7564969      20:24:00  32.055099  34.779915     20920
# 12927          435  8736001      18:42:59  32.055122  34.780029     20916
# 13003          437  8879301      08:35:00  32.055908  34.779297      5189
# 13057          438  8826201      13:40:00  32.055054  34.779667      5189
# 13061          443  7793169      10:23:01  32.055626  34.779747     20920
# 13138          445  7517769      10:40:00  32.055408  34.779995     20916
# 13210          446  7647969      07:46:02  32.055275  34.779861      5189
# 13269          453  7655069      22:10:27  32.055756  34.779400      5189
# 13324          455  7548969      10:55:00  32.055157  34.780117     20916
# 13408          456  7621669      18:46:41  32.054958  34.779774      5189
# 13472          457  8825301      22:45:38  32.055824  34.779152      5189
# 13520          458  7708169      11:10:00  32.055801  34.779434      5214
# 13589          460  7563969      11:53:00  32.055645  34.779537     20920
# 13663          463  8735801      18:15:01  32.056004  34.779282      5214
# 13739          466  8730201      11:23:00  32.055050  34.779911     20920
# 13811          467  7655669      12:20:06  32.055779  34.779194      5189
# ...            ...      ...           ...        ...        ...       ...
# 112721        4007  8725401      08:10:45  32.055817  34.779343      5214
# 112791        4008  8835501      17:58:01  32.055019  34.779976      5189
# 112854        4011  7775169      19:10:01  32.055614  34.779644      5214
# 112924        4013  7535069      18:24:13  32.055115  34.779781     20920
# 112998        4016  8875901      10:56:13  32.055073  34.779907      5189
# 113053        4017  7602969      10:48:41  32.056370  34.780266      5189
# 113096        4018  7611969      10:19:00  32.055962  34.779705      5189
# 113149        4019  8821101      14:55:41  32.055927  34.779343      5189
# 113197        4020  8860901      21:40:35  32.055668  34.779495      5189
# 113244        4026  7654269      08:05:24  32.056496  34.779888      5189
# 113299        4031  7643869      10:31:00  32.055634  34.779598      5189
# 113351        4032  7511269      07:46:47  32.055191  34.779991     20916
# 113431        4033  7708169      07:05:00  32.055000  34.779922      5214
# 113503        4034  7622069      05:10:00  32.055859  34.779289      5189
# 113543        4036  8837201      07:59:00  32.055908  34.779270      5189
# 113600        4037  8830701      09:35:25  32.055431  34.779835      5189
# 113658        4038  8825301      09:56:33  32.055004  34.779869     20920
# 113726        4041  8878401      07:44:47  32.055798  34.779701      5189
# 113784        4045  8892901      07:30:00  32.055710  34.779358      5189
# 113824        4047  7793169      19:27:19  32.055035  34.779972     20920
# 113896        4048  8839501      16:11:31  32.055416  34.779892      5189
# 113948        4052  7647269      18:25:33  32.055653  34.779530      5189
# 114014        4053  8827201      20:55:26  32.055679  34.779419      5189
# 114071        4054  7646969      08:07:00  32.055313  34.780201      5189
# 114105        4055  7602969      10:48:13  32.056374  34.780258      5189
# 114157        4058  8873901      15:02:58  32.055035  34.779976      5189
# 114215        4059  8875901      10:55:29  32.054993  34.779842      5189
# 114276        4062  7794269      10:35:28  32.055790  34.779285     20920
# 114347        4066  8873401      08:49:00  32.055004  34.779903      5189
# 114410        4067  7646969      21:15:01  32.055614  34.779549      5189
# 114461        4068  7570269      07:46:10  32.055130  34.779789     20916
# 114542        4069  8812901      16:54:33  32.055923  34.779255      5189
# 114599        4070  7646569      14:04:14  32.056084  34.778374      5189
# 114657        4071  7643869      06:46:12  32.054962  34.779781      5189
# 114714        4074  7646969      12:49:35  32.055466  34.780029      5189
# 114770        4075  7774969      14:23:50  32.055698  34.779865     20920
# 114832        4077  7647469      18:29:39  32.054993  34.779793      5189
# 114895        4078  7646569      09:55:05  32.054981  34.779812      5189
# 114959        4079  7711169      20:42:00  32.054913  34.779690     20916
# 114960        4082  7513969      15:16:57  32.055000  34.779835     20920
# 115042        4089  7542869      17:59:43  32.055691  34.782066     20916
# 115120        4090  7566169      14:32:41  32.055374  34.780151     20916
# 115209        4091  7611969      10:19:11  32.055843  34.779354      5189
# 115277        4093  8827201      17:27:13  32.055115  34.779884      5189
# 115329        4096  8821001      07:23:57  32.055168  34.779903      5189
# 115390        4097  8825301      15:16:43  32.055191  34.779896      5189
# 115447        4098  8845201      09:40:01  32.055912  34.779335      5189
# 115503        4099  8861601      08:01:57  32.056133  34.778370      5189
# 115560        4101  7629769      06:38:00  32.055710  34.779682      5189
# 115611        4105  7647469      22:27:22  32.055389  34.780128      5189
# 115658        4108  8887401      21:40:23  32.055775  34.779797      5189
# 115704        4110  7648169      09:25:37  32.054981  34.779724      5189
# 115758        4111  7570269      12:40:46  32.055763  34.779263     20916
# 115831        4112  8860201      17:56:18  32.055466  34.779835      5189
# 115894        4116  7508769      17:06:49  32.054981  34.779869     20912
# 115958        4117  7602969      10:48:28  32.056381  34.780251      5189
# 116005        4118  7646869      14:53:24  32.056099  34.778378      5189
# 116071        4120  7602969      00:00:29  32.109119  34.792110      5189
# 116111        4121  8877601      05:51:54  32.055286  34.780079      5189
# 116160        4122  8826201      13:40:15  32.055790  34.779274      5189
# 116221        4123  7647469      18:26:35  32.054966  34.779854      5189
# 116288        4125  7647969      07:44:01  32.055695  34.779499      5189
# 116344        4126  7513969      07:40:00  32.055920  34.779331     20916
# 116422        4127  7646969      12:45:00  32.055920  34.779289      5189
# 116483        4129  7569969      09:57:09  32.055031  34.779919     20920
# 116550        4132  8783801      21:13:46  32.055141  34.780052     20920
# 116607        4135  7564969      16:53:37  32.055595  34.779675     20920
# 116682        4137  7646569      13:58:00  32.055893  34.779266      5189
# 116742        4139  7646669      07:38:04  32.055054  34.780010      5189
# 116803        4143  8873401      08:50:46  32.056072  34.778381      5189
# 116840        4144  7775169      07:27:27  32.137745  34.835155     20916
# 116842        4145  8887401      21:40:22  32.055656  34.779720      5189
# 116887        4146  8825301      07:59:29  32.055683  34.779434      5189
# 116945        4149  7646569      09:57:23  32.055286  34.779968      5189
# 117000        4150  8825301      06:09:08  32.056038  34.778374      5189
# 117049        4153  7793169      10:23:00  32.055710  34.779747     20920
# 117118        4156  7637069      05:25:02  32.055901  34.779297      5189
# 117166        4158  7647569      12:45:00  32.055725  34.779270      5189
# 117231        4161  8873801      22:45:27  32.055840  34.779228      5189
# 117237        4165  7793169      14:46:01  32.055199  34.779743     20920
# 117323        4166  7647569      16:57:15  32.055168  34.779762      5189
# 117383        4167  8891501      12:43:33  32.055840  34.779335      5189
# 117443        4171  7564969      20:23:14  32.055603  34.779514     20920
# 117497        4172  7602969      07:14:12  32.056343  34.780300      5189
# 117548        4174  7513969      07:00:00  32.055901  34.779324     20912
# 117608        4175  8736601      20:02:54  32.055000  34.779884     20920
# 117668        4178  8707001      17:42:07  32.055649  34.782143     20920
# 117739        4179  7760869      07:25:13  32.055008  34.779922     20916
# 117819        4182  7620669      07:51:00  32.055862  34.779301      5189
# 117879        4186  7565269      10:10:29  32.055069  34.779991      5214
# 117941        4187  7508769      15:10:34  32.055038  34.779926      5214
# 118019        4188  8887701      10:53:00  32.055191  34.780083      5189
# 118071        4191  7514269      09:54:34  32.055164  34.779945     20920
# 118143        4192  7793169      06:21:54  32.056145  34.778316     20916
# 118219        4193  7647569      18:47:26  32.055054  34.779964      5189
# 118277        4195  8824501      20:15:01  32.055798  34.779266      5189
# 118323        4197  7760869      16:05:00  32.055920  34.779282     20912
# 118378        4198  8827201      08:55:00  32.055519  34.779762      5189
# 118450        4200  8812901      14:19:35  32.055752  34.779774      5189
# 118501        4205  7647969      08:45:49  32.055737  34.779484      5189
# 118560        4206  7760869      07:28:49  32.055073  34.779861     20916
# 118643        4208  7565769      12:54:20  32.055050  34.779968     20920
# 118708        4212  7617169      06:00:17  32.055828  34.779293      5189
# 118753        4214  8880401      10:54:29  32.055012  34.779995      5189
# 118810        4216  8786501      13:35:48  32.056271  34.778591     20916
# 118892        4217  8845201      18:13:40  32.056129  34.778343      5189
# 118952        4219  8837801      15:27:57  32.055725  34.779610      5189
# 118953        4221  7653269      15:29:28  32.055176  34.780106      5189
# 119019        4222  7621669      07:09:11  32.060417  34.784565      5189
# 119060        4223  8783801      08:40:00  32.055939  34.779343     20916
# 119138        4225  8887401      17:42:22  32.055119  34.779987      5189
# 119188        4226  7511269      07:00:48  32.054951  34.779778     20912
# 119242        4227  7643869      10:38:35  32.055328  34.782936      5189
# 119292        4230  8856901      07:25:19  32.055073  34.779865      5189
# 119353        4231  8863401      13:22:00  32.055878  34.779312      5189
# 119406        4233  7775269      17:24:34  32.055176  34.780006     20920
# 119479        4234  7643669      11:18:10  32.055016  34.779884      5189
# 119541        4237  8896501      06:55:00  32.055286  34.780231      5189
# 119604        4239  7646969      08:10:54  32.055580  34.779831      5189
# 119665        4240  7517669      05:25:13  32.055813  34.779465     20920
# 119720        4241  7627669      22:10:37  32.055237  34.779732      5189
# 119765        4242  8878001      18:10:09  32.055592  34.779720      5189
# 119825        4245  7790569      15:17:31  32.054928  34.779755     20920
# 119902        4246  8786501      17:53:00  32.055725  34.779514     20920
# 119979        4247  8721201      05:36:39  32.055191  34.780029     20916
# 120034        4249  8887801      19:31:34  32.055225  34.780197      5189
# 120087        4250  8891401      06:02:56  32.056091  34.778358      5189
# 120124        4255  7511269      10:40:00  32.055973  34.779583     20916
# 120193        4258  7563969      05:35:14  32.055519  34.779736     20916
# 120254        4259  8839101      19:35:07  32.055069  34.779949      5189
# 120306        4260  7643669      11:15:01  32.055122  34.779903      5189
# 120370        4261  8707001      11:53:09  32.055092  34.779938     20920
# 120433        4265  7515069      12:23:00  32.055614  34.779739     20920
# 120504        4272  8837201      12:45:46  32.055119  34.779915      5189
# 120558        4275  8873401      08:46:28  32.055695  34.779697      5189
# 120618        4277  7513469      12:40:00  32.055893  34.779331     20916
# 120698        4279  8827201      13:41:54  32.055408  34.779903      5189
# 120756        4280  7646569      13:58:01  32.055645  34.779449      5189
# 120815        4281  8855401      19:55:38  32.055737  34.779381      5189
# 120873        4283  7654269      08:36:25  32.055237  34.780155      5189
# 120914        4284  7564969      20:24:30  32.054993  34.779819     20920
# 120971        4288  8887401      16:40:13  32.055328  34.779709      5189
# 121029        4290  7647769      17:05:00  32.055882  34.779312     20912
# 121083        4291  8891601      06:06:32  32.055035  34.779995      5189
# 121126        4292  7515269      11:40:14  32.055164  34.780167     20916
# 121200        4294  7647669      06:24:00  32.054947  34.779781      5189
# 121250        4295  8825301      11:03:19  32.056049  34.778381      5189
# 121314        4296  7602969      08:10:21  32.056095  34.778370      5189
# 121363        4298  8821101      20:00:01  32.055897  34.779305      5189
# 121417        4301  8861401      15:45:50  32.055061  34.779957      5189
# 121473        4303  7631269      05:25:00  32.055683  34.779381      5189
# 121484        4305  7513469      08:10:43  32.055347  34.780155      5214
# 121554        4308  8882501      11:05:00  32.055740  34.779877      5189
# 121607        4312  8878001      06:11:30  32.055008  34.779938      5189
# 121649        4314  7628769      21:10:00  32.055893  34.779301      5189
# 121696        4315  7516769      19:30:10  32.056076  34.778389      5189
# 121750        4319  7565869      09:12:46  32.055485  34.780209      5214
# 121812        4320  7653769      05:50:40  32.055855  34.779251      5189
# 121843        4329  7662769      09:06:32  32.054951  34.779697      5189
# 121895        4330  7578269      06:25:44  32.055069  34.779991     20916
# 121971        4333  8874901      08:00:28  32.055000  34.779949      5189
# 122026        4335  7793169      10:25:31  32.055779  34.779877     20920
# 122097        4336  7646569      13:58:05  32.055450  34.780231      5189
# 122161        4339  7569169      05:45:45  32.055073  34.779942     20916
# 122231        4340  8898901      07:25:18  32.055237  34.780178      5189
# 122288        4342  7646869      17:12:10  32.055096  34.779892      5214
# 122359        4346  7775269      13:12:43  32.055054  34.779831      5214
# 122427        4354  7569969      09:53:00  32.055199  34.779884     20920
# 122479        4357  8879301      06:30:12  32.055923  34.779270      5189
# 122533        4360  8861401      07:09:20  32.055859  34.779366      5189
# 122587        4361  8883401      11:46:54  32.055168  34.780014      5189
# 122640        4362  8783801      21:10:27  32.055782  34.779331     20920
# 122692        4363  8837201      06:27:39  32.056107  34.778355      5189
# 122726        4368  7517769      09:40:08  32.055073  34.779934     20916
# 122802        4370  8887401      21:40:37  32.055206  34.779842      5189
# 122846        4373  8896501      06:54:44  32.054943  34.779774      5189
# 122897        4375  7643669      11:15:01  32.055206  34.779896      5189
# 122951        4377  8821101      09:45:27  32.054993  34.779800      5189
# 123009        4378  7615069      19:31:26  32.055180  34.779957      5189
# 123063        4379  8760001      18:44:06  32.055828  34.779350     20916
# 123143        4381  7569369      13:36:35  32.055206  34.780170     20916
# 123218        4383  7646869      11:25:00  32.055874  34.779202      5189
# 123274        4386  8745001      18:43:21  32.055202  34.780018     20916
# 123355        4387  8789001      17:53:00  32.055832  34.779476     20920
# 123428        4389  7775169      19:11:57  32.055058  34.779945      5214
# 123492        4391  8715801      17:31:06  32.137829  34.835102     20920
# 123522        4393  8835501      22:10:08  32.055035  34.779884      5189
# 123567        4396  8825701      05:40:17  32.055912  34.779160      5189
# 123615        4399  7563969      05:45:40  32.055038  34.779896     20916
# 123672        4401  8897801      00:00:04  32.100307  34.793453      5189
# 123721        4403  8736001      13:33:35  32.055271  34.780018     20916
# 123807        4406  7611969      10:19:00  32.055901  34.779324      5189
# 123871        4407  7577969      21:11:31  32.055164  34.780128     20920
# 123931        4414  8856901      08:39:08  32.181438  34.870125      5189
# 123937        4415  7550169      10:40:00  32.055889  34.779297     20916
# 124003        4416  8877101      08:45:35  32.055218  34.780216      5189
# 124060        4423  7515269      16:10:01  32.055176  34.779930      5214
# 124133        4425  7648369      08:26:58  32.055542  34.780251      5189
# 124192        4432  7647369      10:07:00  32.055660  34.779549      5189
# 124252        4433  7775169      06:41:26  32.054981  34.779850     20916
# 124339        4434  8878001      15:43:25  32.055008  34.779903      5189
# 124394        4436  8873901      13:30:41  32.055386  34.779907      5189
# 124455        4438  7515269      11:40:00  32.055725  34.779453     20916
# 124529        4439  7643369      16:12:21  32.055286  34.779804      5189
# 124585        4441  8890301      16:26:04  32.055870  34.779228      5189
# 124645        4442  7515269      11:40:22  32.055084  34.780079     20916
# 124719        4443  8887401      11:31:33  32.055676  34.779522      5189
# 124770        4444  8853401      20:35:11  32.055725  34.779488      5189
# 124818        4446  7565169      11:24:55  32.056622  34.779163     20920
# 124820        4447  7569969      14:30:00  32.056618  34.779446     20916
# 124905        4450  7577969      09:37:11  32.055103  34.779896      5214
# 124966        4452  7708169      11:10:00  32.055832  34.779339      5214
# 125034        4453  7653269      15:01:04  32.055676  34.779499      5189
# 125095        4456  8800101      09:19:10  32.055195  34.779888      5189
# 125152        4460  7513969      06:15:00  32.055614  34.779682     20916
# 125238        4463  7760869      16:05:15  32.055054  34.779972     20912
# 125303        4465  7708169      19:40:49  32.055061  34.779987     20916
# 125366        4467  7647469      22:25:24  32.055107  34.779980      5189
# 125395        4469  8783801      08:44:02  32.054981  34.779854     20916
# 125449        4470  7565269      14:20:00  32.055954  34.779404     20920
# 125510        4472  8837201      12:57:22  32.066238  34.786648      5189
# 125568        4473  8874901      14:23:32  32.056095  34.778381      5189
# 125623        4476  7647969      14:55:01  32.055706  34.779415      5189
# 125672        4477  7653169      07:32:07  32.055000  34.779884      5189
# 125728        4478  7515269      16:17:39  32.061665  34.784893      5214
# 125794        4480  8825301      19:08:13  32.055408  34.779781      5189
# 125844        4481  8830001      13:24:46  32.055008  34.779865      5189
# 125898        4482  8827201      13:40:24  32.055912  34.779205      5189
# 125951        4484  8877101      20:46:04  32.056065  34.778370      5189
# 125996        4485  8873801      00:00:09  32.163261  34.824062      5189
# 126039        4486  7513969      15:20:45  32.056076  34.778362     20920
# 126109        4488  8883401      11:45:57  32.055103  34.779842      5189
# 126165        4491  7621669      18:49:14  32.055023  34.779884      5189
# 126213        4493  7611969      10:19:53  32.055676  34.779774      5189
# 126278        4494  7653869      06:38:40  32.055618  34.779427      5189
# 126338        4495  8864501      17:57:00  32.055054  34.779861      5189
# 126410        4500  7760869      20:02:47  32.055115  34.780067     20920
# 126472        4501  7648169      13:04:02  32.055138  34.780018      5189
# 126526        4506  7513969      15:17:18  32.055218  34.780064     20920
# 126602        4508  8837201      09:50:38  32.056072  34.778358      5189
# 126642        4509  7655869      06:07:03  32.055817  34.779190      5189
# 126694        4510  8837401      17:58:03  32.054951  34.779762      5189
# 126758        4511  8845201      13:04:18  32.055870  34.779213      5189
# 126813        4512  8878001      15:45:08  32.055054  34.779957      5189
# 126876        4513  8887401      11:31:00  32.055912  34.779278      5189
# 126931        4514  8717301      18:10:44  32.055752  34.779312      5214
# 127003        4521  7569969      08:05:00  32.055771  34.779366     20912
# 127055        4524  7548969      07:05:07  32.055695  34.779430      5214
# 127111        4525  7623569      09:15:55  32.055820  34.779293      5189
# 127167        4526  8882501      07:16:43  32.055157  34.779945      5189
#
#         line_index                                  coordinates
# 0              169  POINT (32.05493927001953 34.77975082397461)
# 67             248   POINT (32.05502700805664 34.7798957824707)
# 142            405   POINT (32.05565643310547 34.7794303894043)
# 185            461  POINT (32.05580902099609 34.77936935424805)
# 248            532  POINT (32.05563354492188 34.77962112426758)
# 321            633  POINT (32.05553817749023 34.77983093261719)
# 389            878  POINT (32.05567932128906 34.77943420410156)
# 443            958  POINT (32.05557632446289 34.77970504760742)
# 496           1259  POINT (32.05514526367188 34.77995681762695)
# 565           1339  POINT (32.05581665039063 34.77935028076172)
# 632           1542  POINT (32.05508422851563 34.77989959716797)
# 697           1795  POINT (32.05521774291992 34.78018951416016)
# 754           1863  POINT (32.05584716796875 34.77931213378906)
# 809           2183  POINT (32.05498123168945 34.77985382080078)
# 873           2435    POINT (32.055908203125 34.77925491333008)
# 925           2498  POINT (32.05585861206055 34.77935028076172)
# 975           2558  POINT (32.05582809448242 34.77933883666992)
# 1041          2635   POINT (32.05530166625977 34.7801628112793)
# 1125          2732  POINT (32.05582427978516 34.77930068969727)
# 1179          2801  POINT (32.05585098266602 34.77936553955078)
# 1242          3070  POINT (32.05498886108398 34.77972030639648)
# 1313          3150  POINT (32.05501174926758 34.77984619140625)
# 1370          3223  POINT (32.07361221313477 34.79090118408203)
# 1373          3376  POINT (32.05608367919922 34.77838134765625)
# 1428          3444  POINT (32.05584716796875 34.77933120727539)
# 1497          3653  POINT (32.06682586669922 34.78688049316406)
# 1532          3834  POINT (32.05496978759766 34.77985000610352)
# 1597          3909  POINT (32.05588912963867 34.77920913696289)
# 1659          4179  POINT (32.05495834350586 34.77983856201172)
# 1722          4332  POINT (32.16968536376953 34.85294723510742)
# 1737          4420   POINT (32.05578994750977 34.7797737121582)
# 1793          4654  POINT (32.05508422851563 34.77993392944336)
# 1861          4734  POINT (32.05561065673828 34.77969741821289)
# 1864          5004  POINT (32.05521774291992 34.78018188476563)
# 1922          5159   POINT (32.05635070800781 34.7801628112793)
# 1978          5229  POINT (32.05593109130859 34.77930450439453)
# 2034          5297  POINT (32.09358978271484 34.81757736206055)
# 2082          5613  POINT (32.05663681030273 34.77966690063477)
# 2152          5888  POINT (32.05563354492188 34.77954483032227)
# 2236          6196    POINT (32.0558967590332 34.7792854309082)
# 2286          6415  POINT (32.05607223510742 34.77837753295898)
# 2327          6575  POINT (32.05512619018555 34.77985763549805)
# 2382          6639  POINT (32.05606842041016 34.77835464477539)
# 2421          6702  POINT (32.06115341186523 34.78490829467773)
# 2425          6853  POINT (32.05498886108398 34.77986145019531)
# 2473          6912  POINT (32.05577087402344 34.77937698364258)
# 2537          7007  POINT (32.05559539794922 34.77963256835937)
# 2539          7169  POINT (32.05592727661133 34.77935791015625)
# 2590          7403  POINT (32.05559539794922 34.77961730957031)
# 2653          7479  POINT (32.05602645874023 34.77937698364258)
# 2717          7791  POINT (32.05503463745117 34.77990341186523)
# 2721          7886  POINT (32.05527877807617 34.77999877929688)
# 2780          7971  POINT (32.05497360229492 34.77976608276367)
# 2832          8224  POINT (32.05607986450195 34.77834320068359)
# 2895          8422  POINT (32.05502700805664 34.77993392944336)
# 2970          8511    POINT (32.05527496337891 34.780029296875)
# 3030          8594  POINT (32.05509185791016 34.77999877929688)
# 3097          8678  POINT (32.09543609619141 34.79425048828125)
# 3133          8806  POINT (32.05501556396484 34.77984237670898)
# 3195          8898  POINT (32.05522537231445 34.78009033203125)
# 3238          8954  POINT (32.05567932128906 34.77980422973633)
# 3299          9194       POINT (32.05571746826172 34.779296875)
# 3338          9248  POINT (32.05506896972656 34.77980422973633)
# 3408          9448   POINT (32.0555534362793 34.77992248535156)
# 3461          9513  POINT (32.05590057373047 34.77936935424805)
# 3527          9935   POINT (32.05563735961914 34.7797737121582)
# 3600         10024  POINT (32.05615615844727 34.77838134765625)
# 3656         10278  POINT (32.05569458007813 34.77978134155273)
# 3714         10539  POINT (32.18039703369141 34.87457275390625)
# 3756         10541  POINT (32.05593490600586 34.77923965454102)
# 3814         10615  POINT (32.05517959594727 34.78017425537109)
# 3898         10864     POINT (32.05517578125 34.77986526489258)
# 3903         10885  POINT (32.05497741699219 34.77973937988281)
# 3975         11245   POINT (32.05560684204102 34.7796516418457)
# 4043         11340  POINT (32.05501937866211 34.77994155883789)
# 4047         11356  POINT (32.05608367919922 34.77930450439453)
# 4113         11456  POINT (32.05559539794922 34.77964019775391)
# 4190         11636  POINT (32.05507659912109 34.77988052368164)
# 4242         11789  POINT (32.05630493164063 34.78005981445313)
# 4332         11897  POINT (32.05604553222656 34.77838134765625)
# 4383         12123  POINT (32.05570220947266 34.77936172485352)
# 4439         12294  POINT (32.05594253540039 34.77930450439453)
# 4481         12733  POINT (32.05601119995117 34.77928161621094)
# 4537         12879  POINT (32.05508422851563 34.77998733520508)
# 4540         12892  POINT (32.05508422851563 34.77977752685547)
# 4597         13134  POINT (32.06684112548828 34.78679275512695)
# 4598         13135   POINT (32.05588912963867 34.7793083190918)
# 4649         13317     POINT (32.05517578125 34.77995300292969)
# 4718         13639  POINT (32.05557250976563 34.77971267700195)
# 4794         13924  POINT (32.05576705932617 34.77942657470703)
# 4865         14110  POINT (32.05559539794922 34.77960968017578)
# 4926         14316  POINT (32.18203353881836 34.86727905273437)
# 4970         14603  POINT (32.05586624145508 34.77926254272461)
# 4973         14619   POINT (32.0561408996582 34.77838134765625)
# 5038         14692  POINT (32.05561447143555 34.77950668334961)
# 5093         14765   POINT (32.0563850402832 34.78019332885742)
# 5172         14874  POINT (32.05611038208008 34.77838516235352)
# 5228         14965   POINT (32.05514907836914 34.7799072265625)
# 5277         15355  POINT (32.05510330200195 34.77998733520508)
# 5353         15437  POINT (32.05570983886719 34.77937698364258)
# 5407         15509  POINT (32.05574798583984 34.77973175048828)
# 5478         15894  POINT (32.05570983886719 34.77978897094727)
# 5509         15951  POINT (32.05494689941406 34.77973937988281)
# 5580         16284  POINT (32.05573654174805 34.77947998046875)
# 5663         16383   POINT (32.0558967590332 34.77928161621094)
# 5729         16736  POINT (32.05587005615234 34.77934265136719)
# 5819         16841  POINT (32.14184951782227 34.80188369750977)
# 5853         17229   POINT (32.0549430847168 34.77978897094727)
# 5888         17400  POINT (32.05588912963867 34.77935028076172)
# 5968         17507  POINT (32.05562210083008 34.77959823608398)
# 6030         17589  POINT (32.05509948730469 34.77939224243164)
# 6087         17797  POINT (32.05502319335937 34.77988433837891)
# 6146         17869  POINT (32.15227127075195 34.80615615844727)
# 6175         18040  POINT (32.05588150024414 34.77924346923828)
# 6227         18286   POINT (32.05577850341797 34.7795524597168)
# 6282         18355   POINT (32.0550422668457 34.77989959716797)
# 6345         18427  POINT (32.05591201782227 34.77927398681641)
# 6379         18500  POINT (32.05509567260742 34.78004455566406)
# 6431         18573  POINT (32.05582046508789 34.77928924560547)
# 6499         18660  POINT (32.05612182617188 34.77839660644531)
# 6570         18827  POINT (32.05609512329102 34.77837371826172)
# 6633         18931   POINT (32.05569458007813 34.7797737121582)
# 6717         19035  POINT (32.05499267578125 34.77984237670898)
# 6776         19122  POINT (32.05511856079102 34.77997589111328)
# 6831         19205  POINT (32.05573654174805 34.77981948852539)
# 6880         19271  POINT (32.05515670776367 34.78008651733398)
# 6945         19342   POINT (32.0550537109375 34.77979278564453)
# 7010         19427  POINT (32.11307907104492 34.79278182983398)
# 7052         19570  POINT (32.05509567260742 34.77984619140625)
# 7104         19775  POINT (32.05605316162109 34.77835464477539)
# 7159         19855   POINT (32.0550422668457 34.77990341186523)
# 7234         20002  POINT (32.05522537231445 34.77997970581055)
# 7324         20230  POINT (32.05511474609375 34.77997970581055)
# 7381         20347  POINT (32.17420196533203 34.85181045532227)
# 7432         20358  POINT (32.05582809448242 34.77928924560547)
# 7496         20457  POINT (32.05585861206055 34.77924346923828)
# 7549         20522  POINT (32.05503082275391 34.77991104125977)
# 7607         20598  POINT (32.05591583251953 34.77927017211914)
# 7667         20687  POINT (32.05495834350586 34.77981567382813)
# 7733         20842  POINT (32.05584716796875 34.77971267700195)
# ...
# 113197      327164  POINT (32.05566787719727 34.77949523925781)
# 113244      327632  POINT (32.05649566650391 34.77988815307617)
# 113299      328128  POINT (32.05563354492188 34.77959823608398)
# 113351      328203  POINT (32.05519104003906 34.77999114990234)
# 113431      328293  POINT (32.05500030517578 34.77992248535156)
# 113503      328376  POINT (32.05585861206055 34.77928924560547)
# 113543      328490    POINT (32.055908203125 34.77927017211914)
# 113600      328579   POINT (32.0554313659668 34.77983474731445)
# 113658      328654  POINT (32.05500411987305 34.77986907958984)
# 113726      328925   POINT (32.0557975769043 34.77970123291016)
# 113784      329269  POINT (32.05570983886719 34.77935791015625)
# 113824      329422  POINT (32.05503463745117 34.77997207641602)
# 113896      329514  POINT (32.05541610717773 34.77989196777344)
# 113948      329855    POINT (32.0556526184082 34.7795295715332)
# 114014      329954   POINT (32.05567932128906 34.7794189453125)
# 114071      330028  POINT (32.05531311035156 34.78020095825195)
# 114105      330100  POINT (32.05637359619141 34.78025817871094)
# 114157      330312  POINT (32.05503463745117 34.77997589111328)
# 114215      330383  POINT (32.05499267578125 34.77984237670898)
# 114276      330689   POINT (32.05578994750977 34.7792854309082)
# 114347      331001  POINT (32.05500411987305 34.77990341186523)
# 114410      331090  POINT (32.05561447143555 34.77954864501953)
# 114461      331150  POINT (32.05513000488281 34.77978897094727)
# 114542      331253  POINT (32.05592346191406 34.77925491333008)
# 114599      331342  POINT (32.05608367919922 34.77837371826172)
# 114657      331412  POINT (32.05496215820313 34.77978134155273)
# 114714      331634    POINT (32.05546569824219 34.780029296875)
# 114770      331700  POINT (32.05569839477539 34.77986526489258)
# 114832      331811  POINT (32.05499267578125 34.77979278564453)
# 114895      331894  POINT (32.05498123168945 34.77981185913086)
# 114959      331970  POINT (32.05491256713867 34.77968978881836)
# 114960      332160  POINT (32.05500030517578 34.77983474731445)
# 115042      332943  POINT (32.05569076538086 34.78206634521484)
# 115120      333034   POINT (32.05537414550781 34.7801513671875)
# 115209      333136  POINT (32.05584335327148 34.77935409545898)
# 115277      333301  POINT (32.05511474609375 34.77988433837891)
# 115329      333505  POINT (32.05516815185547 34.77990341186523)
# 115390      333594   POINT (32.05519104003906 34.7798957824707)
# 115447      333676  POINT (32.05591201782227 34.77933502197266)
# 115503      333746  POINT (32.05613327026367 34.77836990356445)
# 115560      333937  POINT (32.05570983886719 34.77968215942383)
# 115611      334282  POINT (32.05538940429688 34.78012847900391)
# 115658      334346    POINT (32.0557746887207 34.7797966003418)
# 115704      334488  POINT (32.05498123168945 34.77972412109375)
# 115758      334565  POINT (32.05576324462891 34.77926254272461)
# 115831      334649  POINT (32.05546569824219 34.77983474731445)
# 115894      335001  POINT (32.05498123168945 34.77986907958984)
# 115958      335080  POINT (32.05638122558594 34.78025054931641)
# 116005      335135  POINT (32.05609893798828 34.77837753295898)
# 116071      335308   POINT (32.1091194152832 34.79211044311523)
# 116111      335347   POINT (32.0552864074707 34.78007888793945)
# 116160      335407  POINT (32.05578994750977 34.77927398681641)
# 116221      335488  POINT (32.05496597290039 34.77985382080078)
# 116288      335673  POINT (32.05569458007813 34.77949905395508)
# 116344      335757   POINT (32.0559196472168 34.77933120727539)
# 116422      335850   POINT (32.0559196472168 34.77928924560547)
# 116483      336055   POINT (32.05503082275391 34.7799186706543)
# 116550      336287  POINT (32.05514144897461 34.78005218505859)
# 116607      336561   POINT (32.05559539794922 34.7796745300293)
# 116682      336746  POINT (32.05589294433594 34.77926635742188)
# 116742      336911   POINT (32.0550537109375 34.78001022338867)
# 116803      337323  POINT (32.05607223510742 34.77838134765625)
# 116840      337404  POINT (32.13774490356445 34.83515548706055)
# 116842      337422  POINT (32.05565643310547 34.77972030639648)
# 116887      337482  POINT (32.05568313598633 34.77943420410156)
# 116945      337770   POINT (32.0552864074707 34.77996826171875)
# 117000      337848  POINT (32.05603790283203 34.77837371826172)
# 117049      338078  POINT (32.05570983886719 34.77974700927734)
# 117118      338427       POINT (32.05590057373047 34.779296875)
# 117166      338560  POINT (32.05572509765625 34.77927017211914)
# 117231      338796  POINT (32.05583953857422 34.77922821044922)
# 117237      339032  POINT (32.05519866943359 34.77974319458008)
# 117323      339156  POINT (32.05516815185547 34.77976226806641)
# 117383      339229  POINT (32.05583953857422 34.77933502197266)
# 117443      339555  POINT (32.05560302734375 34.77951431274414)
# 117497      339620  POINT (32.05634307861328 34.78030014038086)
# 117548      339759  POINT (32.05590057373047 34.77932357788086)
# 117608      339856  POINT (32.05500030517578 34.77988433837891)
# 117668      339977  POINT (32.05564880371094 34.78214263916016)
# 117739      340066  POINT (32.05500793457031 34.77992248535156)
# 117819      340304  POINT (32.05586242675781 34.77930068969727)
# 117879      340628  POINT (32.05506896972656 34.77999114990234)
# 117941      340699  POINT (32.05503845214844 34.77992630004883)
# 118019      340802  POINT (32.05519104003906 34.78008270263672)
# 118071      341066   POINT (32.0551643371582 34.77994537353516)
# 118143      341155  POINT (32.05614471435547 34.77831649780273)
# 118219      341240   POINT (32.0550537109375 34.77996444702148)
# 118277      341397   POINT (32.0557975769043 34.77926635742188)
# 118323      341603   POINT (32.0559196472168 34.77928161621094)
# 118378      341682  POINT (32.05551910400391 34.77976226806641)
# 118450      341962   POINT (32.05575180053711 34.7797737121582)
# 118501      342323  POINT (32.05573654174805 34.77948379516602)
# 118560      342406  POINT (32.05507278442383 34.77986145019531)
# 118643      342633  POINT (32.05504989624023 34.77996826171875)
# 118708      343000  POINT (32.05582809448242 34.77929306030273)
# 118753      343155  POINT (32.05501174926758 34.77999496459961)
# 118810      343312  POINT (32.05627059936523 34.77859115600586)
# 118892      343411  POINT (32.05612945556641 34.77834320068359)
# 118952      343575  POINT (32.05572509765625 34.77960968017578)
# 118953      343608     POINT (32.05517578125 34.78010559082031)
# 119019      343696  POINT (32.06041717529297 34.78456497192383)
# 119060      343761  POINT (32.05593872070313 34.77934265136719)
# 119138      343948  POINT (32.05511856079102 34.77998733520508)
# 119188      344011  POINT (32.05495071411133 34.77977752685547)
# 119242      344081  POINT (32.05532836914063 34.78293609619141)
# 119292      344327  POINT (32.05507278442383 34.77986526489258)
# 119353      344425  POINT (32.05587768554688 34.77931213378906)
# 119406      344593     POINT (32.05517578125 34.78000640869141)
# 119479      344686  POINT (32.05501556396484 34.77988433837891)
# 119541      344904   POINT (32.0552864074707 34.78023147583008)
# 119604      345002  POINT (32.05558013916016 34.77983093261719)
# 119665      345096  POINT (32.05581283569336 34.77946472167969)
# 119720      345158  POINT (32.05523681640625 34.77973175048828)
# 119765      345216  POINT (32.05559158325195 34.77972030639648)
# 119825      345452  POINT (32.05492782592773 34.77975463867188)
# 119902      345551  POINT (32.05572509765625 34.77951431274414)
# 119979      345648    POINT (32.05519104003906 34.780029296875)
# 120034      345901  POINT (32.05522537231445 34.78019714355469)
# 120087      345969  POINT (32.05609130859375 34.77835845947266)
# 120124      346427  POINT (32.05597305297852 34.77958297729492)
# 120193      346693  POINT (32.05551910400391 34.77973556518555)
# 120254      346757  POINT (32.05506896972656 34.77994918823242)
# 120306      346820  POINT (32.05512237548828 34.77990341186523)
# 120370      346894  POINT (32.05509185791016 34.77993774414063)
# 120433      347214  POINT (32.05561447143555 34.77973937988281)
# 120504      347795  POINT (32.05511856079102 34.77991485595703)
# 120558      348256  POINT (32.05569458007813 34.77969741821289)
# 120618      348535  POINT (32.05589294433594 34.77933120727539)
# 120698      348787   POINT (32.0554084777832 34.77990341186523)
# 120756      348850  POINT (32.05564498901367 34.77944946289063)
# 120815      348924  POINT (32.05573654174805 34.77938079833984)
# 120873      349064  POINT (32.05523681640625 34.78015518188477)
# 120914      349144  POINT (32.05499267578125 34.77981948852539)
# 120971      349447  POINT (32.05532836914063 34.77970886230469)
# 121029      349666  POINT (32.05588150024414 34.77931213378906)
# 121083      349733  POINT (32.05503463745117 34.77999496459961)
# 121126      349785   POINT (32.0551643371582 34.78016662597656)
# 121200      349984  POINT (32.05494689941406 34.77978134155273)
# 121250      350041  POINT (32.05604934692383 34.77838134765625)
# 121314      350121  POINT (32.05609512329102 34.77836990356445)
# 121363      350237   POINT (32.0558967590332 34.77930450439453)
# 121417      350443  POINT (32.05506134033203 34.77995681762695)
# 121473      350584  POINT (32.05568313598633 34.77938079833984)
# 121484      350631  POINT (32.05534744262695 34.78015518188477)
# 121554      350838  POINT (32.05574035644531 34.77987670898437)
# 121607      351050  POINT (32.05500793457031 34.77993774414063)
# 121649      351184  POINT (32.05589294433594 34.77930068969727)
# 121696      351247  POINT (32.05607604980469 34.77838897705078)
# 121750      351550  POINT (32.05548477172852 34.78020858764648)
# 121812      351626  POINT (32.05585479736328 34.77925109863281)
# 121843      352654  POINT (32.05495071411133 34.77969741821289)
# 121895      352738  POINT (32.05506896972656 34.77999114990234)
# 121971      353050  POINT (32.05500030517578 34.77994918823242)
# 122026      353275  POINT (32.05577850341797 34.77987670898437)
# 122097      353361  POINT (32.05545043945313 34.78023147583008)
# 122161      353584  POINT (32.05507278442383 34.77994155883789)
# 122231      353662  POINT (32.05523681640625 34.78017807006836)
# 122288      353789  POINT (32.05509567260742 34.77989196777344)
# 122359      354105   POINT (32.0550537109375 34.77983093261719)
# 122427      354764  POINT (32.05519866943359 34.77988433837891)
# 122479      354931  POINT (32.05592346191406 34.77927017211914)
# 122533      355211  POINT (32.05585861206055 34.77936553955078)
# 122587      355280  POINT (32.05516815185547 34.78001403808594)
# 122640      355347  POINT (32.05578231811523 34.77933120727539)
# 122692      355407  POINT (32.05610656738281 34.77835464477539)
# 122726      355904  POINT (32.05507278442383 34.77993392944336)
# 122802      356084  POINT (32.05520629882813 34.77984237670898)
# 122846      356249    POINT (32.0549430847168 34.7797737121582)
# 122897      356486   POINT (32.05520629882813 34.7798957824707)
# 122951      356614  POINT (32.05499267578125 34.77980041503906)
# 123009      356702  POINT (32.05517959594727 34.77995681762695)
# 123063      356776  POINT (32.05582809448242 34.77935028076172)
# 123143      356970  POINT (32.05520629882813 34.78017044067383)
# 123218      357127  POINT (32.05587387084961 34.77920150756836)
# 123274      357367   POINT (32.05520248413086 34.7800178527832)
# 123355      357459  POINT (32.05583190917969 34.77947616577148)
# 123428      357625  POINT (32.05505752563477 34.77994537353516)
# 123492      357766   POINT (32.1378288269043 34.83510208129883)
# 123522      357881  POINT (32.05503463745117 34.77988433837891)
# 123567      358109  POINT (32.05591201782227 34.77915954589844)
# 123615      358184   POINT (32.05503845214844 34.7798957824707)
# 123672      358416  POINT (32.10030746459961 34.79345321655273)
# 123721      358539   POINT (32.05527114868164 34.7800178527832)
# 123807      358906  POINT (32.05590057373047 34.77932357788086)
# 123871      358984   POINT (32.0551643371582 34.78012847900391)
# 123931      359417  POINT (32.18143844604492 34.87012481689453)
# 123937      359423       POINT (32.05588912963867 34.779296875)
# 124003      359499  POINT (32.05521774291992 34.78021621704102)
# 124060      360266     POINT (32.05517578125 34.77993011474609)
# 124133      360442   POINT (32.0555419921875 34.78025054931641)
# 124192      361110  POINT (32.05566024780273 34.77954864501953)
# 124252      361187  POINT (32.05498123168945 34.77985000610352)
# 124339      361290  POINT (32.05500793457031 34.77990341186523)
# 124394      361470   POINT (32.05538558959961 34.7799072265625)
# 124455      361627  POINT (32.05572509765625 34.77945327758789)
# 124529      361714   POINT (32.0552864074707 34.77980422973633)
# 124585      361882  POINT (32.05587005615234 34.77922821044922)
# 124645      361966  POINT (32.05508422851563 34.78007888793945)
# 124719      362049   POINT (32.0556755065918 34.77952194213867)
# 124770      362114  POINT (32.05572509765625 34.77948760986328)
# 124818      362251   POINT (32.05662155151367 34.7791633605957)
# 124820      362263  POINT (32.05661773681641 34.77944564819336)
# 124905      362513   POINT (32.05510330200195 34.7798957824707)
# 124966      362642  POINT (32.05583190917969 34.77933883666992)
# 125034      362721   POINT (32.0556755065918 34.77949905395508)
# 125095      362983  POINT (32.05519485473633 34.77988815307617)
# 125152      363327  POINT (32.05561447143555 34.77968215942383)
# 125238      363552   POINT (32.0550537109375 34.77997207641602)
# 125303      363695  POINT (32.05506134033203 34.77998733520508)
# 125366      363847  POINT (32.05510711669922 34.77997970581055)
# 125395      364067  POINT (32.05498123168945 34.77985382080078)
# 125449      364155  POINT (32.05595397949219 34.77940368652344)
# 125510      364302  POINT (32.06623840332031 34.78664779663086)
# 125568      364373  POINT (32.05609512329102 34.77838134765625)
# 125623      364661  POINT (32.05570602416992 34.77941513061523)
# 125672      364725  POINT (32.05500030517578 34.77988433837891)
# 125728      364806  POINT (32.06166458129883 34.78489303588867)
# 125794      365020   POINT (32.0554084777832 34.77978134155273)
# 125844      365085  POINT (32.05500793457031 34.77986526489258)
# 125898      365150  POINT (32.05591201782227 34.77920532226563)
# 125951      365353  POINT (32.05606460571289 34.77836990356445)
# 125996      365437  POINT (32.16326141357422 34.82406234741211)
# 126039      365460  POINT (32.05607604980469 34.77836227416992)
# 126109      365645  POINT (32.05510330200195 34.77984237670898)
# 126165      365895  POINT (32.05502319335937 34.77988433837891)
# 126213      366074    POINT (32.0556755065918 34.7797737121582)
# 126278      366154  POINT (32.05561828613281 34.77942657470703)
# 126338      366225   POINT (32.0550537109375 34.77986145019531)
# 126410      366683  POINT (32.05511474609375 34.78006744384766)
# 126472      366762   POINT (32.05513763427734 34.7800178527832)
# 126526      367116  POINT (32.05521774291992 34.78006362915039)
# 126602      367310  POINT (32.05607223510742 34.77835845947266)
# 126642      367373  POINT (32.05581665039063 34.77919006347656)
# 126694      367438  POINT (32.05495071411133 34.77976226806641)
# 126758      367526  POINT (32.05587005615234 34.77921295166016)
# 126813      367596   POINT (32.0550537109375 34.77995681762695)
# 126876      367674  POINT (32.05591201782227 34.77927780151367)
# 126931      367751  POINT (32.05575180053711 34.77931213378906)
# 127003      368218  POINT (32.05577087402344 34.77936553955078)
# 127055      368557   POINT (32.05569458007813 34.7794303894043)
# 127111      368627  POINT (32.05582046508789 34.77929306030273)
# 127167      368711  POINT (32.05515670776367 34.77994537353516)
#
# [2248 rows x 8 columns]

# %%
train_similarity_matrix = train_gdf.groupby(['trip_index',
                'route_id']).apply(lambda trip: find_route_id_similarity(trip, route_stats_stops_gdf, route_stats_unique))

# %% [markdown]
# long runtime...

# %%
train_similarity_matrix.head()
# Out:
#                        5189_mean  5189_cnt  5214_mean  5214_cnt  20912_mean  \
# trip_index route_id
# 3          20920    0   0.513514        37   0.913043        46    0.810811
# 4          20916    0   0.459459        37   0.913043        46    0.810811
# 6          5189     0   1.000000        37   0.369565        46    0.513514
# 7          20916    0   0.459459        37   0.913043        46    0.810811
# 8          20920    0   0.513514        37   0.913043        46    0.810811
#
#                        20912_cnt  20916_mean  20916_cnt  20917_mean  \
# trip_index route_id
# 3          20920    0         37    0.793103         58    0.809524
# 4          20916    0         37    1.000000         58    1.000000
# 6          5189     0         37    0.293103         58    0.349206
# 7          20916    0         37    1.000000         58    1.000000
# 8          20920    0         37    0.793103         58    0.809524
#
#                        20917_cnt  20920_mean  20920_cnt
# trip_index route_id
# 3          20920    0         63    1.000000         45
# 4          20916    0         63    1.000000         45
# 6          5189     0         63    0.488889         45
# 7          20916    0         63    1.000000         45
# 8          20920    0         63    1.000000         45

# %%
#train_similarity_matrix

# %% [markdown]
# ###  match trip_index to route_id using  similarity metric

# %%
def match_route_id(trip, route_stats_unique, min_match_prob = 0.8, floor_val = 0.05):
    
    match_summary = {}  
    
    # drop route_ids with % prob < min_match_prob
    for route_id in route_stats_unique.route_id:
        
        # for each route 
        if trip[str(route_id)+'_mean'] >=  min_match_prob:
            match_summary[route_id] = round(math.floor(trip[str(route_id)+'_mean'] / floor_val) * floor_val,2)
    
    if not match_summary:
        return 'No match'
    
    else:
    
    # choose best match
        max_match = max(match_summary.values())
        
        match_summary = {key: val for key, val in match_summary.items() if val == max_match}
        
        if len(match_summary) == 1:
            
            # if
            return list(match_summary.keys())[0]
        
        else:
            max_match_route_ids = match_summary.keys()
            match_summary = {} # reset match_summary to contain route_ids number of stops 
            for route_id in max_match_route_ids:
                match_summary[route_id] = trip[str(route_id)+'_cnt']
            
            #match_summary = sorted(match_summary.items(), key=lambda x: x[1], reverse=True)
            
            max_match = max(match_summary.values())
            
            match_summary = {key: val for key, val in match_summary.items() if val == max_match}
            
            if len(match_summary) == 1:
                
                # if
                return list(match_summary.keys())[0]
            else:
                
                # if
                return 'No match'

# %% [markdown]
# ## for each trip, apply match route id, with unique route stats. and than transform it to dataframe

# %%
train_similarity_matrix.tail(1).apply(lambda trip: match_route_id(trip, route_stats_unique), axis=1).to_frame()
# Out:
#                           0
# trip_index route_id
# 4526       5189     0  5189

# %%
train_trips = train_similarity_matrix.apply(lambda trip: match_route_id(trip, route_stats_unique), axis=1).to_frame()

train_trips.rename(columns = {0: 'route_id_pred'}, inplace=True)

train_trips.reset_index(inplace=True)

train_trips.drop(columns=['level_2'], inplace=True)

train_trips['route_id_pred_true'] = np.where(train_trips.route_id==train_trips.route_id_pred,1,0)

# %%
train_trips[::200]
# Out:
#       trip_index  route_id route_id_pred  route_id_pred_true
# 0              3     20920         20920                   1
# 200          375     20920         20920                   1
# 400          808     20916         20917                   0
# 600         1184      5189          5189                   1
# 800         1589      5189          5189                   1
# 1000        1992      5189          5189                   1
# 1200        2393      5189          5189                   1
# 1400        2796      5189          5189                   1
# 1600        3205      5189          5189                   1
# 1800        3614     20920         20920                   1
# 2000        4011      5214          5214                   1
# 2200        4438     20916         20917                   0

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# ### phase 1 - precision and recall

# %% [markdown]
# #### recall

# %%
train_trips.groupby('route_id')['route_id_pred_true'].value_counts().unstack().fillna(0).astype(int)
# Out:
# route_id_pred_true    0     1
# route_id
# 5189                 87  1241
# 5214                 31   163
# 20912                12    54
# 20916               268     0
# 20920                19   373

# %%
train_trips.groupby('route_id')['route_id_pred_true'].value_counts(normalize=True).round(2).unstack().fillna(0)
# Out:
# route_id_pred_true     0     1
# route_id
# 5189                0.07  0.93
# 5214                0.16  0.84
# 20912               0.18  0.82
# 20916               1.00  0.00
# 20920               0.05  0.95

# %%
train_trips.groupby('route_id')['route_id_pred'].value_counts(normalize=0).round(2).unstack().fillna(0).astype(int)
# Out:
# route_id_pred  5189  5214  20912  20917  20920  No match
# route_id
# 5189           1241     0      0      0      0        87
# 5214              0   163      0      0      1        30
# 20912             0     0     54      0      0        12
# 20916             0     0      0    232      0        36
# 20920             0     0      0      0    373        19

# %%
train_trips.groupby('route_id')['route_id_pred'].value_counts(normalize=True).round(2).unstack().fillna(0)
# Out:
# route_id_pred  5189  5214  20912  20917  20920  No match
# route_id
# 5189           0.93  0.00   0.00   0.00   0.00      0.07
# 5214           0.00  0.84   0.00   0.00   0.01      0.15
# 20912          0.00  0.00   0.82   0.00   0.00      0.18
# 20916          0.00  0.00   0.00   0.87   0.00      0.13
# 20920          0.00  0.00   0.00   0.00   0.95      0.05

# %% [markdown]
# ####  precision

# %%
train_trips.groupby('route_id_pred')['route_id_pred_true'].value_counts(normalize=0).unstack().fillna(0).astype(int)
# Out:
# route_id_pred_true    0     1
# route_id_pred
# 5189                  0  1241
# 5214                  0   163
# 20912                 0    54
# 20917               232     0
# 20920                 1   373
# No match            184     0

# %%
train_trips.groupby('route_id_pred')['route_id_pred_true'].value_counts(normalize=True).round(2).unstack().fillna(0)
# Out:
# route_id_pred_true    0    1
# route_id_pred
# 5189                0.0  1.0
# 5214                0.0  1.0
# 20912               0.0  1.0
# 20917               1.0  0.0
# 20920               0.0  1.0
# No match            1.0  0.0

# %%
round(train_trips.route_id_pred_true.mean(),2)
# Out:
# 0.81

# %% [markdown]
# note that "No match" label doesn't exist in tha real data

# %% [markdown]
# ### phase 2 - test some examples

# %%
def plot_prediction(trip_index,train_trips = train_trips, train_gdf = train_gdf, route_stats_stops_gdf = route_stats_stops_gdf):
    
    pred = train_gdf[(train_gdf['trip_index']==trip_index)&(train.lat>0)]
    
    route_id = pred.route_id.values[0]
    
    route_id_pred = train_trips[train_trips['trip_index']==trip_index].route_id_pred.values[0]
    
    actual = route_stats_stops_gdf[(route_stats_stops_gdf['route_id']==route_id)]
    
    title = 'trip_index: {} - pred: {}, actual: {}'.format(trip_index, route_id_pred, route_id)
    
    fig = plt.figure(num=None, figsize=(10, 8))
    
    ax = actual.plot(markersize=200)
    
    ax.set_title(title)
    
    pred.plot(ax=ax)

# %%
train_trips.merge(train_similarity_matrix, on = 'trip_index', how = 'inner')[::500]
# Out:
#       trip_index  route_id route_id_pred  route_id_pred_true  5189_mean  \
# 0              3     20920         20920                   1   0.513514
# 500          986      5189          5189                   1   1.000000
# 1000        1992      5189          5189                   1   1.000000
# 1500        3008     20916      No match                   0   0.054054
# 2000        4011      5214          5214                   1   0.459459
#
#       5189_cnt  5214_mean  5214_cnt  20912_mean  20912_cnt  20916_mean  \
# 0           37   0.913043        46    0.810811         37    0.793103
# 500         37   0.369565        46    0.513514         37    0.293103
# 1000        37   0.369565        46    0.513514         37    0.293103
# 1500        37   0.043478        46    0.054054         37    0.034483
# 2000        37   1.000000        46    0.783784         37    0.793103
#
#       20916_cnt  20917_mean  20917_cnt  20920_mean  20920_cnt
# 0            58    0.809524         63    1.000000         45
# 500          58    0.349206         63    0.488889         45
# 1000         58    0.349206         63    0.488889         45
# 1500         58    0.031746         63    0.044444         45
# 2000         58    0.809524         63    1.000000         45

# %% [markdown]
# #### "No Match" pred

# %%
plot_prediction(62)

# %%
plot_prediction(493)

# %%
plot_prediction(2067)

# %% [markdown]
# #### True pred

# %%
plot_prediction(235)

# %%
plot_prediction(277)

# %% [markdown]
# #### False Pred

# %%
plot_prediction(2220)

# %%
plot_prediction(3260)

# %% [markdown]
# # Test

# %% [markdown]
# ### get test data

# %%
test = pd.read_csv('test.csv', encoding='windows-1255')

# %%
test.head()
# Out:
#    trip_index   bus_id time_recorded        lat        lon  line_index
# 0           1  8878101      15:29:00  32.055294  34.779953           0
# 1           1  8878101      15:34:01  32.055889  34.779289           5
# 2           1  8878101      15:35:12  32.056080  34.778332           6
# 3           1  8878101      15:38:34  32.058559  34.784031           9
# 4           1  8878101      15:39:33  32.060497  34.784584          10

# %% [markdown]
# ### transform test to GeoDataFrame

# %%
test['coordinates'] = list(zip(test.lat, test.lon))
test['coordinates'] = test['coordinates'].apply(Point)

test_gdf = gpd.GeoDataFrame(test, geometry='coordinates')

# %% [markdown]
# ### use similarity metric - test data

# %%
test_similarity_matrix = test_gdf.groupby(['trip_index'])\
                .apply(lambda trip: find_route_id_similarity(trip, route_stats_stops_gdf, route_stats_unique))

# %% [markdown]
# ###  match using  similarity metric - test data

# %%
test_trips = test_similarity_matrix.apply(lambda trip: match_route_id(trip, route_stats_unique), axis=1).to_frame()

test_trips.rename(columns = {0: 'route_id_pred'}, inplace=True)

test_trips.reset_index(inplace=True)

test_trips.drop(columns=['level_1'], inplace=True)

# %% [markdown]
# ### send test results to csv

# %%
test_trips.head()
# Out:
#    trip_index route_id_pred
# 0           1          5189
# 1           2          5189
# 2           5          5189
# 3          10          5189
# 4          11         20920

# %%
test_trips.to_csv('test_trips.csv')
